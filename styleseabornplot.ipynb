# %% [markdown]
# <a href="https://colab.research.google.com/github/githubtuhin96/UDEMY-ML-COURSE/blob/main/styleseabornplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
#sns.despine()
sns.despine(left=True,bottom=True)

# %%
plt.figure(figsize=(12,3))
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
#sns.despine()
sns.despine(left=True,bottom=True)

# %%
sns.set_context('talk',font_scale=2)
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)

# %%
sns.lmplot(x='tip',y='size',data=tips,hue='sex',palette='summer')
