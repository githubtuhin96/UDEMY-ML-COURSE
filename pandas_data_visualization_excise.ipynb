# %% [markdown]
# <a href="https://colab.research.google.com/github/githubtuhin96/UDEMY-ML-COURSE/blob/main/pandas_data_visualization_excise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1=pd.read_csv('/content/df1')
df1
# Out:
#      Unnamed: 0         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
df2=pd.read_csv('/content/df2')
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind="hist",bins=30)

# %%
df1['A'].plot.hist()

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.area(alpha=.1)

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-9779bd9f885c> in <module>
# ----> 1 df1.plot.line(x=df1.index,y='B',figsize=(12,3))
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#    1038         as coordinates.
#    1039         """
# -> 1040         return self(kind="line", x=x, y=y, **kwargs)
#    1041
#    1042     @Appender(
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df1.plot.scatter(x='A',y='B',c="C",cmap="coolwarm")

# %%
df1.plot.scatter(x='A',y='B',c="C",s=df1['C']*50)

# %%
df2.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=["a","b"])
df
# Out:
#             a         b
# 0   -0.315489 -0.299055
# 1   -1.010715  1.176833
# 2   -0.062170 -0.603282
# 3    1.162873  0.231682
# 4   -1.051452  1.045080
# ..        ...       ...
# 995 -0.355530 -0.179564
# 996  1.652486  0.686369
# 997  0.610809 -0.420802
# 998 -0.064127  1.056152
# 999  0.398803 -0.780693
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',cmap="coolwarm",gridsize=22)

# %%
df['a'].plot.kde()

# %%
df2.plot.density()
