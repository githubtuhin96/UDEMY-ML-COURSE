# %% [markdown]
# <a href="https://colab.research.google.com/github/githubtuhin96/UDEMY-ML-COURSE/blob/main/choroplethmaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import plotly.plotly as py

# %%
# !pip install chart-studio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 KB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import plotly
#from chart_studio import plotly

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data=dict( type='choropleth',
          locations=['AZ','CA','NY'],
          locationmode='USA-states',
          colorscale='Greens',
          text=['Arizona','california','text 3'],
          z=[1.0,2.0,3.0],
          colorbar={'title':'Colorbar Title Goes Here'}
          )

# %%
data
# Out:
# {'type': 'choropleth',
#  'locations': ['AZ', 'CA', 'NY'],
#  'locationmode': 'USA-states',
#  'colorscale': 'Greens',
#  'text': ['Arizona', 'california', 'text 3'],
#  'z': [1.0, 2.0, 3.0],
#  'colorbar': {'title': 'Colorbar Title Goes Here'}}

# %%
layout=dict(geo={'scope':'usa'})

# %%
import plotly.graph_objects as go

# %%
choromap=go.Figure(data = [data],layout = layout)

# %%
plotly.io.renderers.default = 'colab'

# %%
iplot(choromap)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
df = pd.read_excel('/content/Book (1).xlsx')

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1      Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0          NaN        NaN             NaN        NaN            NaN
# 1          NaN       code           state   category  total exports
# 2          NaN         AL         Alabama      state        1390.63
# 3          NaN         AK          Alaska      state          13.31
# 4          NaN         AZ         Arizona      state        1463.17
# 5          NaN         AR        Arkansas      state        3586.02
# 6          NaN         CA      California      state       16472.88
# 7          NaN         CO        Colorado      state        1851.33
# 8          NaN         CT     Connecticut      state         259.62
# 9          NaN         DE        Delaware      state         282.19
# 10         NaN         FL         Florida      state        3764.09
# 11         NaN         GA         Georgia      state        2860.84
# 12         NaN         HI          Hawaii      state         401.84
# ...

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
df.drop(0, axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-c01897a5cc6b> in <module>
# ----> 1 df.drop(0, axis=1,inplace=True)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#    Unnamed: 1      Unnamed: 2 Unnamed: 3     Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1        code           state   category  total exports       beef       pork
# 2          AL         Alabama      state        1390.63       34.4       10.6
# 3          AK          Alaska      state          13.31        0.2        0.1
# 4          AZ         Arizona      state        1463.17       71.3       17.9
# 5          AR        Arkansas      state        3586.02       53.2       29.4
# 6          CA      California      state       16472.88      228.7       11.1
# 7          CO        Colorado      state        1851.33      261.4         66
# 8          CT     Connecticut      state         259.62        1.1        0.1
# 9          DE        Delaware      state         282.19        0.4        0.6
# 10         FL         Florida      state        3764.09       42.6        0.9
# 11         GA         Georgia      state        2860.84         31       18.9
# ...

# %%
df.columns = df.iloc[0]
df
# Out:
# 1   code           state  category  total exports   beef    pork  poultry  \
# 1   code           state  category  total exports   beef    pork  poultry
# 2     AL         Alabama     state        1390.63   34.4    10.6      481
# 3     AK          Alaska     state          13.31    0.2     0.1        0
# 4     AZ         Arizona     state        1463.17   71.3    17.9        0
# 5     AR        Arkansas     state        3586.02   53.2    29.4    562.9
# 6     CA      California     state       16472.88  228.7    11.1    225.4
# 7     CO        Colorado     state        1851.33  261.4      66       14
# 8     CT     Connecticut     state         259.62    1.1     0.1      6.9
# 9     DE        Delaware     state         282.19    0.4     0.6    114.7
# 10    FL         Florida     state        3764.09   42.6     0.9     56.9
# 11    GA         Georgia     state        2860.84     31    18.9    630.4
# 12    HI          Hawaii     state         401.84      4     0.7      1.3
# ...

# %%
df.drop(1,inplace=True)

# %%
df.columns
# Out:
# Index(['code', 'state', 'category', 'total exports', 'beef', 'pork', 'poultry',
#        'dairy', 'fruits fresh', 'fruits proc', 'total fruits', 'veggies fresh',
#        'veggies proc', 'total veggies', 'corn', 'wheat', 'cotton'],
#       dtype='object', name=1)

# %%
data=dict(type='choropleth',
          colorscale='viridis',
          locations=df['code'],
          locationmode='USA-states',
          z=df['total exports'],
          text=df['state'],
          marker= dict(line=dict(color='rgb(12,12,12)',width=1)),
          colorbar={'title':'Millions USD'})

# %%
layout=dict(title= '2011 us agriculture exports by state',geo=dict(scope='usa',showlakes=True, lakecolor='rgb(85,173,240)'))

# %%
choromap2=(go.Figure(data=[data],layout=layout))

# %%
iplot(choromap2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
